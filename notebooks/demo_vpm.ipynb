# %% [markdown]
# # visualize_pixel_map demo
# Tsviki Y. Hirsh
#
# Jan 1st 2026

# %%
import visualize_pixel_map as vpm

# %%
data = vpm.Data("/work/nuclear/neutron_event_analyzer/tests/data/neutrons")
# Out:
# Found AssociatedResults folder with 1 CSV file(s)
# Concatenating 1 CSV file(s)
# Loaded 98425 rows
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data = vpm.Data("/work/nuclear/neutron_event_analyzer/tests/data/neutrons")
#
# File ~/micromamba/lib/python3.13/site-packages/visualize_pixel_map/analyse.py:77, in Data.__init__(self, data_path, start_time, end_time, time_step, sensor_size, neutron_id, verbosity, auto_associate, association_mode, settings)
#      74         if self.has_event_id:
#      75             print(f"  - Contains event associations")
# ---> 77 self._normalize_columns(sensor_size)
#
# File ~/micromamba/lib/python3.13/site-packages/visualize_pixel_map/analyse.py:353, in Data._normalize_columns(self, sensor_size)
#     350     self.df = self.df[final_cols]
#     352 else:
# --> 353     raise ValueError(
# ...

# %%
data.times
# Out:
# {'range': (np.float64(1.5325e-05), np.float64(0.00694058125)),
#  'bins': 1701,
#  'bin_keys': [1.532e-05,
#   1.533e-05,
#   1.534e-05,
#   2.5280000000000002e-05,
#   2.529e-05,
#   2.5300000000000002e-05,
#   2.531e-05,
#   2.532e-05,
#   2.533e-05,
#   4.042e-05]}

# %%
data.plot(color_by="tot",show_legend=True,toa_range=(0,6e-3))
# Out:
# Filtered data: 0 rows (from 0 original)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 data.plot(color_by="tot",show_legend=True,toa_range=(0,6e-3))
#
# File ~/micromamba/lib/python3.13/site-packages/visualize_pixel_map/analyse.py:552, in Data.plot(self, key, neutron_id_filter, photons, pixels, events, toa_range, color_by, zoom_region, zoom_size, custom_color, show_background, despine, time_bins, show_scale, cmap, show_labels, show_legend, auto_zoom_margin)
#     549     self.prepare_histograms(bins_edges)
#     551 # Plot with filtered histograms
# --> 552 self._do_plot(key, neutron_id_filter, zoom_region, zoom_size, custom_color,
#     553              show_background, despine, time_bins, show_scale, cmap,
#     554              show_labels, show_legend, auto_zoom_margin, color_by)
#     556 # Restore original data
# ...
