# %%
import visualize_pixel_map as vpm

# %%
data = vpm.Data()

# %%
data.plot(despine=False,zoom_size=25,cmap="viridis_r",time_bins=50,show_scale=True)

# %%
data.plot(key=590,despine=False,zoom_size=25,cmap="magma_r",time_bins=80,show_scale=True)

# %%
data.plot(key=635,despine=False,zoom_region=[60,80,175,220],cmap="magma_r",
          time_bins=60,show_scale=True,)
