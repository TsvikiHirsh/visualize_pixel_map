# %%
import visualize_pixel_map as vpm

# %%
data = vpm.Data()

# %%
data.plot(despine=False,custom_color="royalblue",zoom_size=20)

# %%
data.plot(start_key_idx=590,despine=False,custom_color="indianred",zoom_size=20)
